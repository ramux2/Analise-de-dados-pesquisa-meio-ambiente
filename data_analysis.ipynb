# %% [markdown]
# <h1>Tratamento de dados - pesquisa de campo<h1>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("dados_pesquisa.csv", delimiter=';')

# %%
df = pd.DataFrame(dados)

# %%
df.head()
# Out:
#    ID Faixa etária          Nivel de escolaridade  \
# 0   1   51 ou mais        Ensino médio incompleto
# 1   2   51 ou mais  Ensino fundamental incompleto
# 2   3   51 ou mais  Ensino fundamental incompleto
# 3   4   51 ou mais  Ensino fundamental incompleto
# 4   5   51 ou mais  Ensino fundamental incompleto
#
#   Sabe o que é lixo tóxico e químico? (Exemplo: lâmpadas, óleo de cozinha, remédios vencidos, pilhas e entre outros)   \
# 0  Sabe que nao  podem jogar em lixo comum descar...
# 1  Sabe que as lâmpadas, televisões, bateria de c...
# 2  Não, mas com os exemplos ela ficou surpresa ao...
# 3                                               Não
# 4                             Sabe, pilha, aparelho
#
#         Onde você faz o descarte desse tipo de lixo?  \
# 0                                   Lixo específico
# 1  Descarte nas lojas do centro de campo largo, q...
# 2                                            No lixo
# 3                         Coleta de lixo / caminhão
# ...

# %%
df = df.dropna(axis=1)

# %%
df.head(5)
# Out:
#    ID Faixa etária          Nivel de escolaridade  \
# 0   1   51 ou mais        Ensino médio incompleto
# 1   2   51 ou mais  Ensino fundamental incompleto
# 2   3   51 ou mais  Ensino fundamental incompleto
# 3   4   51 ou mais  Ensino fundamental incompleto
# 4   5   51 ou mais  Ensino fundamental incompleto
#
#   Sabe o que é lixo tóxico e químico? (Exemplo: lâmpadas, óleo de cozinha, remédios vencidos, pilhas e entre outros)   \
# 0  Sabe que nao  podem jogar em lixo comum descar...
# 1  Sabe que as lâmpadas, televisões, bateria de c...
# 2  Não, mas com os exemplos ela ficou surpresa ao...
# 3                                               Não
# 4                             Sabe, pilha, aparelho
#
#         Onde você faz o descarte desse tipo de lixo?  \
# 0                                   Lixo específico
# 1  Descarte nas lojas do centro de campo largo, q...
# 2                                            No lixo
# 3                         Coleta de lixo / caminhão
# ...

# %%
coluna_tratada = pd.DataFrame(df['Onde você faz o descarte desse tipo de lixo? TRATADO'])
coluna_tratada.head(10)
# Out:
#   Onde você faz o descarte desse tipo de lixo? TRATADO
# 0                             Coleta regular de lixo
# 1                     Descarte em locais específicos
# 2                      Descarte de itens específicos
# 3                      Descarte de itens específicos
# 4                          Separação de lixo em casa
# 5                             Coleta regular de lixo
# 6                          Separação de lixo em casa
# 7                     Descarte em locais específicos
# 8                      Descarte de itens específicos
# 9                     Descarte em locais específicos

# %%
dados = pd.read_csv('dados_tratados.csv')

# %%
df_tratado = pd.DataFrame(dados)
df_tratado.head(5)
# Out:
#   Faixa etária          Nivel de escolaridade  \
# 0   51 ou mais        Ensino médio incompleto
# 1   51 ou mais  Ensino fundamental incompleto
# 2   51 ou mais  Ensino fundamental incompleto
# 3   51 ou mais  Ensino fundamental incompleto
# 4   51 ou mais  Ensino fundamental incompleto
#
#   Sabe o que é lixo tóxico e químico? (Exemplo: lâmpadas, óleo de cozinha, remédios vencidos, pilhas e entre outros)   \
# 0  Sabe que nao  podem jogar em lixo comum descar...
# 1  Sabe que as lâmpadas, televisões, bateria de c...
# 2  Não, mas com os exemplos ela ficou surpresa ao...
# 3                                               Não
# 4                             Sabe, pilha, aparelho
#
#   Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                          Consciência ambiental
# 1                          Consciência ambiental
# 2                                Desconhecimento
# 3                                Desconhecimento
# 4                        Conhecimento específico
# ...

# %%
df_tratado = df_tratado.drop(df_tratado.columns[7], axis=1)
df_tratado.head(5)
# Out:
#   Faixa etária          Nivel de escolaridade  \
# 0   51 ou mais        Ensino médio incompleto
# 1   51 ou mais  Ensino fundamental incompleto
# 2   51 ou mais  Ensino fundamental incompleto
# 3   51 ou mais  Ensino fundamental incompleto
# 4   51 ou mais  Ensino fundamental incompleto
#
#   Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                          Consciência ambiental
# 1                          Consciência ambiental
# 2                                Desconhecimento
# 3                                Desconhecimento
# 4                        Conhecimento específico
#
#   Resposta – Você realiza a separação de lixo tóxico, químico e comum?  \
# 0                                  Realiza separação
# 1                     Realiza separação parcialmente
# 2                                  Realiza separação
# 3                            Não realiza a separação
# 4                                  Realiza separação
#
# ...

# %%
df_tratado['Resposta – Onde você faz o descarte desse tipo de lixo?'] = coluna_tratada

# %%
df_tratado.head(5)
# Out:
#   Faixa etária          Nivel de escolaridade  \
# 0   51 ou mais        Ensino médio incompleto
# 1   51 ou mais  Ensino fundamental incompleto
# 2   51 ou mais  Ensino fundamental incompleto
# 3   51 ou mais  Ensino fundamental incompleto
# 4   51 ou mais  Ensino fundamental incompleto
#
#   Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                          Consciência ambiental
# 1                          Consciência ambiental
# 2                                Desconhecimento
# 3                                Desconhecimento
# 4                        Conhecimento específico
#
#   Resposta – Você realiza a separação de lixo tóxico, químico e comum?  \
# 0                                  Realiza separação
# 1                     Realiza separação parcialmente
# 2                                  Realiza separação
# 3                            Não realiza a separação
# 4                                  Realiza separação
#
# ...

# %%
df_tratado.to_csv('dados_organizados.csv', index=False)

# %%
dados = pd.read_csv('dados_organizados.csv')
dados
# Out:
#           Faixa etária          Nivel de escolaridade  \
# 0           51 ou mais        Ensino médio incompleto
# 1           51 ou mais  Ensino fundamental incompleto
# 2           51 ou mais  Ensino fundamental incompleto
# 3           51 ou mais  Ensino fundamental incompleto
# 4           51 ou mais  Ensino fundamental incompleto
# ..                 ...                            ...
# 75  Entre 21 a 25 anos  Ensino fundamental incompleto
# 76          51 ou mais  Ensino fundamental incompleto
# 77  Entre 31 a 50 anos        Ensino médio incompleto
# 78                 NaN                            NaN
# 79                 NaN                            NaN
#
#    Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                           Consciência ambiental
# 1                           Consciência ambiental
# 2                                 Desconhecimento
# 3                                 Desconhecimento
# 4                         Conhecimento específico
# ...

# %%
dados.con
dados
# Out:
#           Faixa etária          Nivel de escolaridade  \
# 0           51 ou mais        Ensino médio incompleto
# 1           51 ou mais  Ensino fundamental incompleto
# 2           51 ou mais  Ensino fundamental incompleto
# 3           51 ou mais  Ensino fundamental incompleto
# 4           51 ou mais  Ensino fundamental incompleto
# ..                 ...                            ...
# 73  Entre 31 a 50 anos    Ensino fundamental completo
# 74  Entre 31 a 50 anos        Ensino médio incompleto
# 75  Entre 21 a 25 anos  Ensino fundamental incompleto
# 76          51 ou mais  Ensino fundamental incompleto
# 77  Entre 31 a 50 anos        Ensino médio incompleto
#
#    Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                           Consciência ambiental
# 1                           Consciência ambiental
# 2                                 Desconhecimento
# 3                                 Desconhecimento
# 4                         Conhecimento específico
# ...

# %%
dados.isnull().sum()
# Out:
# Faixa etária                                                                                         0
# Nivel de escolaridade                                                                                0
# Resposta – Sabe o que é lixo tóxico e químico?                                                       0
# Resposta – Você realiza a separação de lixo tóxico, químico e comum?                                 0
# Resposta – Onde você acha que é o local ideal para realizar o descarte dentro da comunidade?         0
# Resposta – Sabe como o descarte incorreto desses lixos pode afetar o meio ambiente e sua família?    0
# Respostas – Tem algum incentivo de órgãos governamentais para o descarte desse tipo de lixo?         1
# Respostas – Porque você acha importante o desenvolvimento desse projeto na comunidade?               0
# Resposta – Onde você faz o descarte desse tipo de lixo?                                              0
# dtype: int64

# %%
dados['Respostas – Tem algum incentivo de órgãos governamentais para o descarte desse tipo de lixo?'][77] = 'Não há incentivo'

# %%
dados
# Out:
#           Faixa etária          Nivel de escolaridade  \
# 0           51 ou mais        Ensino médio incompleto
# 1           51 ou mais  Ensino fundamental incompleto
# 2           51 ou mais  Ensino fundamental incompleto
# 3           51 ou mais  Ensino fundamental incompleto
# 4           51 ou mais  Ensino fundamental incompleto
# ..                 ...                            ...
# 73  Entre 31 a 50 anos    Ensino fundamental completo
# 74  Entre 31 a 50 anos        Ensino médio incompleto
# 75  Entre 21 a 25 anos  Ensino fundamental incompleto
# 76          51 ou mais  Ensino fundamental incompleto
# 77  Entre 31 a 50 anos        Ensino médio incompleto
#
#    Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                           Consciência ambiental
# 1                           Consciência ambiental
# 2                                 Desconhecimento
# 3                                 Desconhecimento
# 4                         Conhecimento específico
# ...

# %%
dados.to_csv('dados_organizados.csv', index=False)

# %%
dados_visualizar = pd.read_csv('dados_organizados.csv')
dados_visualizar
# Out:
#           Faixa etária          Nivel de escolaridade  \
# 0           51 ou mais        Ensino médio incompleto
# 1           51 ou mais  Ensino fundamental incompleto
# 2           51 ou mais  Ensino fundamental incompleto
# 3           51 ou mais  Ensino fundamental incompleto
# 4           51 ou mais  Ensino fundamental incompleto
# ..                 ...                            ...
# 73  Entre 31 a 50 anos    Ensino fundamental completo
# 74  Entre 31 a 50 anos        Ensino médio incompleto
# 75  Entre 21 a 25 anos  Ensino fundamental incompleto
# 76          51 ou mais  Ensino fundamental incompleto
# 77  Entre 31 a 50 anos        Ensino médio incompleto
#
#    Resposta – Sabe o que é lixo tóxico e químico?  \
# 0                           Consciência ambiental
# 1                           Consciência ambiental
# 2                                 Desconhecimento
# 3                                 Desconhecimento
# 4                         Conhecimento específico
# ...
