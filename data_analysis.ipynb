# %% [markdown]
# <h1>Análise de dados - pesquisa de campo<h1>

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting seaborn
# ...
#      -------------------------------------- 293.3/293.3 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.6/7.6 MB 7.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 163.0/163.0 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.0/1.0 MB 4.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.4/55.4 kB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 4.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 1.9 MB/s eta 0:00:00
# ...
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\gustavo.j.siebel\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# ...

# %%
pip install matplotlib
# Out:
# ...
#
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
dados = pd.read_csv("dados_pesquisa.csv", delimiter=';')

# %%
df = pd.DataFrame(dados)

# %%
df.head()
# Out:
#    ID Faixa etária          Nivel de escolaridade
# 0   1   51 ou mais        Ensino médio incompleto  \
# 1   2   51 ou mais  Ensino fundamental incompleto
# 2   3   51 ou mais  Ensino fundamental incompleto
# 3   4   51 ou mais  Ensino fundamental incompleto
# 4   5   51 ou mais  Ensino fundamental incompleto
#
#    Pontos – Nivel de escolaridade
# 0                             NaN  \
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   Sabe o que é lixo tóxico e químico? (Exemplo: lâmpadas, óleo de cozinha, remédios vencidos, pilhas e entre outros)
# 0  Sabe que nao  podem jogar em lixo comum descar...                                                                   \
# 1  Sabe que as lâmpadas, televisões, bateria de c...
# 2  Não, mas com os exemplos ela ficou surpresa ao...
# 3                                               Não
# 4                             Sabe, pilha, aparelho
#
# ...

# %%
df = df.dropna(axis=1)

# %%
df.head(5)
# Out:
#    ID   Hora de início Hora de conclusão      Email Faixa etária
# 0   1  5/7/23 10:17:48   5/7/23 10:26:20  anonymous   51 ou mais  \
# 1   2  5/7/23 10:19:29   5/7/23 10:38:01  anonymous   51 ou mais
# 2   3  5/7/23 15:19:56   5/7/23 15:31:51  anonymous   51 ou mais
# 3   4  5/7/23 15:07:38   5/7/23 15:33:04  anonymous   51 ou mais
# 4   5  5/7/23 15:06:05   5/7/23 15:33:20  anonymous   51 ou mais
#
#            Nivel de escolaridade
# 0        Ensino médio incompleto  \
# 1  Ensino fundamental incompleto
# 2  Ensino fundamental incompleto
# 3  Ensino fundamental incompleto
# 4  Ensino fundamental incompleto
#
#   Sabe o que é lixo tóxico e químico? (Exemplo: lâmpadas, óleo de cozinha, remédios vencidos, pilhas e entre outros)
# 0  Sabe que nao  podem jogar em lixo comum descar...                                                                   \
# 1  Sabe que as lâmpadas, televisões, bateria de c...
# 2  Não, mas com os exemplos ela ficou surpresa ao...
# ...

# %%
sns.countplot(data=df, y=df['Faixa etária'])
plt.title('Distribuição por Categoria')

# Configurando o tipo de gráfico para pizza
plt.pie(df['Faixa etária'], labels=df['Faixa etária'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 5
#       2 plt.title('Distribuição por Categoria')
#       4 # Configurando o tipo de gráfico para pizza
# ----> 5 plt.pie(df['Faixa etária'], labels=df['Faixa etária'], autopct='%1.1f%%')
#       6 plt.axis('equal')
#       7 plt.show()
#
# File c:\Users\gustavo.j.siebel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2799, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2792 @_copy_docstring_and_deprecators(Axes.pie)
#    2793 def pie(
#    2794         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2797         textprops=None, center=(0, 0), frame=False,
# ...

# %%
import openai
import pandas as pd

# Configuração da API da OpenAI
openai.api_key = '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'

classificacoes = []

for elemento in df['Sabe como o descarte incorreto desses lixos pode afetar o meio ambiente e sua família?']:
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt= 'Classifique a seguinte frase entre "Sim", "Não" e "Neutro": ' + elemento,
        max_tokens=1,
        temperature=0,
        top_p=1,
        n=1,
        stop=None,
        log_level='info'
    )

classificacao = response.choices[0].text.strip()
classificacoes.append(classificacao)

df['Classificacao'] = classificacoes
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[45], line 10
#       7 classificacoes = []
#       9 for elemento in df['Sabe como o descarte incorreto desses lixos pode afetar o meio ambiente e sua família?']:
# ---> 10     response = openai.Completion.create(
#      11         engine='text-davinci-003',
#      12         prompt= 'Classifique a seguinte frase entre "Sim", "Não" e "Neutro": ' + elemento,
#      13         max_tokens=1,
#      14         temperature=0,
#      15         top_p=1,
#      16         n=1,
#      17         stop=None,
#      18         log_level='info'
#      19     )
#      21 classificacao = response.choices[0].text.strip()
#      22 classificacoes.append(classificacao)
#
# ...

# %%
df['Classificacao']
# Out:
# Não sabe mas acha que contem toxinas quimicas
# Não sabem, mas tem noção que a química dentro dos equipamentos podem fazer mal à saúde, como o chumbo que pode causar câncer.
# Sim, ela deu os exemplos das enchentes
# Sim, tem um monte de coisa, solo, tudo é afetado
# Muitas coisas, o solo
# Pode afetar um monte de coisa tipo o solo
# Não sei isso influência na minha vida
# Sim
# Pode afetar o rio e a natureza
# Na natureza, rios,
# Plantas, animais, pode prejudicar a alimentação
# Não
# Não.
# Sim
# Não, não tinha conhecimento
# Não eu não entendo muito sobre o assunto
# Não tem noção
# O lixo contaminada o solo
# Sabe a diferença e tem consciência
# Pode prejudicar o meio ambiente
# Não sei muito sobre
# Tem ideia que o terreno fica infertil
# Pegar doenças
# Sim
# Tem uma noção dos efeitos
# Sim
# Poluir os rios
# Tem ideia de onde deve ser feito mas não realiza
# Sim, afeta a água.
# Deixa cheiro
# Afeta gravemente a natureza
# Afeta gravemente a natureza
# ...

# %%
classificar_dados(df, )
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 classificar_dados(df, 'Sabe como o descarte incorreto desses lixos pode afetar o meio ambiente e sua família?')
#
# Cell In[38], line 11, in classificar_dados(df, coluna)
#       8 classificacoes = []
#      10 for elemento in df[coluna]:
# ---> 11     response = openai.Completion.create(
#      12         engine='text-davinci-003',
#      13         prompt=elemento + '\nClassificar:',
#      14         max_tokens=1,
#      15         temperature=0,
#      16         top_p=1,
#      17         n=1,
#      18         stop=None,
#      19         log_level='info'
#      20     )
#      22     classificacao = response.choices[0].text.strip()
#      23     classificacoes.append(classificacao)
#
# ...

# %%
type(df['Sabe como o descarte incorreto desses lixos pode afetar o meio ambiente e sua família?'])
# Out:
# pandas.core.series.Series
